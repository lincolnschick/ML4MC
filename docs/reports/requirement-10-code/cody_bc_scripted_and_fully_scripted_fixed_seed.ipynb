# %% [markdown]
# # README
#
# Since I was running everything in Colab, both the bc_scripted code and the fully_scripted_fixed_seed code are in the same file. It was easier to do it this way so that I wouldn't have to fix the installation for seperate files. Plus, this way I wouldn't need to reinstall stuff into Colab for each file.
#
# Cody

# %% [markdown]
# # Installation

# %%
# %%capture
# !sudo add-apt-repository -y ppa:openjdk-r/ppa
# !sudo apt-get purge openjdk-*
# !sudo apt-get install openjdk-8-jdk
# !sudo apt-get install xvfb
# !sudo apt-get install xserver-xephyr
# !sudo apt-get install -y python3-opengl
# !sudo apt-get install ffmpeg
# !pip3 install gym==0.13.1
# !pip3 install minerl==0.4.4
# !pip3 install pyvirtualdisplay
# !pip3 install -U colabgymrender
# !sudo apt-get install xvfb
# Launch virtual display, which is needed for MineRL
from pyvirtualdisplay import Display
display = Display(visible=False, size=(400, 300))
display.start();

# !sudo apt-get install tigervnc-standalone-server
# !pip3 install opencv-python
# !pip3 install imageio==2.4.1
# !piip3 install pytorch

# %% [markdown]
# # getting_familiar_with_minerl.py

# %%
import gym
import minerl
import cv2
from google.colab.patches import cv2_imshow
from colabgymrender.recorder import Recorder
from time import sleep

SLEEP_TIME = 0.1

def render(observation, environment):
    """A function for rendering MineRL environments. You do not need to worry about this function"""
    if isinstance(environment.unwrapped, minerl.env._singleagent._SingleAgentEnv):
        # Environment is a MineRL one, use OpenCV image showing to show image
        # Make it larger for easier reading
        image = observation["pov"]
        image = cv2.resize(image, (256, 256))
        cv2_imshow(image[..., ::-1])
        # Refresh image
        _ = cv2.waitKey(1)
    else:
        # Regular render
        environment.render()

def main():
    # Create environment
    # Start by using CartPole-v0 for fast debugging and running!
    # Once code works, change to "MineRLObtainDiamond-v0"
    # MineRLNavigateDense-v0
    # MineRLTreechop-v0

    #environment = gym.make("CartPole-v0")
    environment = gym.make("MineRLTreechop-v0")
    #environment = gym.make("MineRLNavigateDense-v0")

    # Add a code that renders the events
    environment = Recorder(environment, './video', fps=30)

    for episode_counter in range(1):
        # Play three episodes

        # Reset the environment (NOTE: With MineRL, this will take time, but with Cartpole is fast)
        observation = environment.reset()

        # Show the game situation for us to see what is going on
        # (Note: Normally you would use `environment.render()`, but because of MineRL
        # we have a different setup)
        render(observation, environment)
        # Wait a moment to give slow brains some time to process the information
        sleep(SLEEP_TIME)

        #raise NotImplementedError("Implement 'step-loop' here to play one episode")

        # TODO step-loop
        # A while-loop until game returns done == True:
        #   - Pick a random action: `environment.action_space` tells what kind actions are available.
        #       You can use `environment.action_space.sample()` to get a random action
        #   - Step game with `environment.step(action)`. See documentation: http://gym.openai.com/docs/
        #   - Print what kind of values you got from the game (observation, reward, done)
        #   - Render current state of the game (see the use of `render` function few lines above)
        #   - Sleep a little bit with `sleep(SLEEP_TIME)` to slow down game
        done = False

        while not done:
            action = environment.action_space.sample()
            obs, reward, done, _ = environment.step(action)
            print(f"\nCount 1:\nObservation: {obs}\nReward: {reward}\nCompletion: {done}\n")
            #render(obs, environment)
            sleep(SLEEP_TIME)

    # Close environment properly
    environment.release()
    environment.close()


# Curious why this is needed?
# See https://stackoverflow.com/questions/419163/what-does-if-name-main-do
if __name__ == "__main__":
    main()
# Out:
# WARNING:minerl.env.malmo.instance.e75b7b:[19:33:50] [main/WARN]: The coremod com.microsoft.Malmo.OverclockingPlugin does not have a MCVersion annotation, it may cause issues with this version of Minecraft
# ERROR:minerl.env.malmo.instance.e75b7b:[19:33:58] [main/ERROR]: The binary patch set is missing. Either you are in a development environment, or things are not going to work!
# ERROR:minerl.env.malmo.instance.e75b7b:[19:33:59] [main/ERROR]: FML appears to be missing any signature data. This is not a good thing
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:00] [main/WARN]: Reference map 'mixins.malmo.refmap.json' for mixins.overclocking.malmomod.json could not be read. If this is a development environment you can ignore this message
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:10] [Client thread/WARN]: Skipping bad option: lastServer:
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:34] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpies4y0fl/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:34] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpies4y0fl/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:34] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpies4y0fl/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:34] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpies4y0fl/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:34] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpies4y0fl/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:34] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpies4y0fl/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:34] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpies4y0fl/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:34] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpies4y0fl/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:34] [Client thread/WARN]: ResourcePack: ignored non-lowercase namespace: MalmoMod in /tmp/tmpies4y0fl/Minecraft/build/libs/MalmoMod-0.37.0-fat.jar
# ERROR:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/INFO]: [STDOUT]: [ERROR] Seed specified was NONE. Expected a long (integer).
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:ambient.cave
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.anvil.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.anvil.destroy
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.anvil.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.anvil.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.anvil.land
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.anvil.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.anvil.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.anvil.use
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.brewing_stand.brew
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.chest.close
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.chest.locked
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.chest.open
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.chorus_flower.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.chorus_flower.grow
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.cloth.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.cloth.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.cloth.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.cloth.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.cloth.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.comparator.click
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.dispenser.dispense
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.dispenser.fail
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.dispenser.launch
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.enchantment_table.use
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.end_gateway.spawn
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.enderchest.close
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.enderchest.open
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.fence_gate.close
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.fence_gate.open
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.fire.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.fire.extinguish
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.furnace.fire_crackle
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.glass.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.glass.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.glass.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.glass.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.glass.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.grass.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.grass.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.grass.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.grass.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.grass.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.gravel.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.gravel.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.gravel.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.gravel.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.gravel.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.iron_door.close
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.iron_door.open
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.iron_trapdoor.close
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.iron_trapdoor.open
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.ladder.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.ladder.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.ladder.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.ladder.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.ladder.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.lava.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.lava.extinguish
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.lava.pop
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.lever.click
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.metal.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.metal.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.metal.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.metal.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.metal.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.metal_pressureplate.click_off
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.metal_pressureplate.click_on
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.note.basedrum
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.note.bass
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.note.harp
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.note.hat
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.note.pling
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.note.snare
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.piston.contract
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.piston.extend
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.portal.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.portal.travel
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.portal.trigger
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.redstone_torch.burnout
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.sand.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.sand.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.sand.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.sand.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.sand.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.shulker_box.close
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.shulker_box.open
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.slime.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.slime.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.slime.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.slime.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.slime.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.snow.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.snow.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.snow.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.snow.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.snow.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.stone.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.stone.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.stone.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.stone.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.stone.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.stone_button.click_off
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.stone_button.click_on
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.stone_pressureplate.click_off
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.stone_pressureplate.click_on
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.tripwire.attach
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.tripwire.click_off
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.tripwire.click_on
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.tripwire.detach
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.water.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.waterlily.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wood.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wood.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wood.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wood.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wood.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wood_button.click_off
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wood_button.click_on
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wood_pressureplate.click_off
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wood_pressureplate.click_on
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wooden_door.close
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wooden_door.open
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wooden_trapdoor.close
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:block.wooden_trapdoor.open
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:enchant.thorns.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.armorstand.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.armorstand.fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.armorstand.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.armorstand.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.arrow.hit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.arrow.hit_player
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.arrow.shoot
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.bat.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.bat.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.bat.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.bat.loop
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.bat.takeoff
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.blaze.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.blaze.burn
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.blaze.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.blaze.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.blaze.shoot
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.bobber.splash
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.bobber.throw
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cat.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cat.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cat.hiss
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cat.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cat.purr
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cat.purreow
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.chicken.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.chicken.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.chicken.egg
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.chicken.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.chicken.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cow.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cow.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cow.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cow.milk
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.cow.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.creeper.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:35] [Client thread/WARN]: Missing sound for event: minecraft:entity.creeper.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.creeper.primed
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.donkey.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.donkey.angry
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.donkey.chest
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.donkey.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.donkey.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.egg.throw
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.elder_guardian.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.elder_guardian.ambient_land
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.elder_guardian.curse
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.elder_guardian.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.elder_guardian.death_land
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.elder_guardian.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.elder_guardian.flop
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.elder_guardian.hurt_land
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.enderdragon.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.enderdragon.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.enderdragon.flap
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.enderdragon.growl
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.enderdragon.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.enderdragon.shoot
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.enderdragon_fireball.explode
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endereye.launch
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermen.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermen.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermen.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermen.scream
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermen.stare
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermen.teleport
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermite.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermite.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermite.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.endermite.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.enderpearl.throw
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.evocation_fangs.attack
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.evocation_illager.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.evocation_illager.cast_spell
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.evocation_illager.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.evocation_illager.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.evocation_illager.prepare_attack
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.evocation_illager.prepare_summon
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.evocation_illager.prepare_wololo
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.experience_bottle.throw
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.experience_orb.pickup
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.firework.blast
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.firework.blast_far
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.firework.large_blast
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.firework.large_blast_far
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.firework.launch
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.firework.shoot
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.firework.twinkle
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.firework.twinkle_far
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.big_fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.burn
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.drink
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.eat
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.explode
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.extinguish_fire
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.small_fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.splash
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.generic.swim
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.ghast.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.ghast.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.ghast.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.ghast.scream
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.ghast.shoot
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.ghast.warn
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.guardian.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.guardian.ambient_land
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.guardian.attack
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.guardian.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.guardian.death_land
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.guardian.flop
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.guardian.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.guardian.hurt_land
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.angry
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.armor
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.breathe
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.eat
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.gallop
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.jump
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.land
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.saddle
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.horse.step_wood
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.hostile.big_fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.hostile.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.hostile.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.hostile.small_fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.hostile.splash
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.hostile.swim
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.husk.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.husk.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.husk.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.husk.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.irongolem.attack
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.irongolem.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.irongolem.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.irongolem.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.item.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.item.pickup
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.itemframe.add_item
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.itemframe.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.itemframe.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.itemframe.remove_item
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.itemframe.rotate_item
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.leashknot.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.leashknot.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.lightning.impact
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.lightning.thunder
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.lingeringpotion.throw
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.llama.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.llama.angry
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.llama.chest
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.llama.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.llama.eat
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.llama.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.llama.spit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.llama.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.llama.swag
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.magmacube.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.magmacube.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.magmacube.jump
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.magmacube.squish
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.minecart.inside
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.minecart.riding
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.mooshroom.shear
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.mule.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.mule.chest
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.mule.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.mule.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.painting.break
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.painting.place
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.pig.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.pig.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.pig.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.pig.saddle
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.pig.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.attack.crit
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.attack.knockback
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.attack.nodamage
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.attack.strong
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.attack.sweep
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.attack.weak
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.big_fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.breath
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.burp
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.levelup
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.small_fall
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.splash
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.player.swim
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.polar_bear.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.polar_bear.baby_ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.polar_bear.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.polar_bear.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.polar_bear.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.polar_bear.warning
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.rabbit.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.rabbit.attack
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.rabbit.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.rabbit.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.rabbit.jump
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.sheep.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.sheep.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.sheep.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.sheep.shear
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.sheep.step
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.shulker.ambient
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.shulker.close
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.shulker.death
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.shulker.hurt
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.shulker.hurt_closed
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.shulker.open
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.shulker.shoot
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.shulker.teleport
# WARNING:minerl.env.malmo.instance.e75b7b:[19:34:36] [Client thread/WARN]: Missing sound for event: minecraft:entity.shulker_bullet.hit
# ...
#         [174, 192, 226],
#         [174, 192, 226],
#         ...,
#         [173, 192, 227],
#         [173, 192, 227],
#         [173, 192, 227]],
#
#        ...,
#
#        [[ 25,  50,  14],
#         [ 28,  56,  16],
#         [ 30,  60,  17],
#         ...,
#         [ 34,  66,  19],
#         [ 33,  65,  18],
#         [ 32,  64,  18]],
#
#        [[ 28,  56,  16],
#         [ 23,  46,  13],
#         [ 26,  51,  14],
#         ...,
#         [ 25,  49,  14],
#         [ 25,  49,  14],
#         [ 23,  45,  13]],
#
#        [[ 29,  57,  16],
#         [ 21,  42,  12],
#         [ 18,  36,  10],
#         ...,
#         [ 29,  57,  16],
#         [ 28,  55,  15],
#         [ 29,  58,  16]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[ 29,  58,  16],
#         [ 26,  52,  14],
#         [ 19,  38,  10],
#         ...,
#         [ 68, 107,  51],
#         [ 68, 108,  51],
#         [ 69, 110,  52]],
#
#        [[ 24,  47,  13],
#         [ 28,  55,  15],
#         [ 24,  48,  13],
#         ...,
#         [ 67, 106,  50],
#         [ 71, 112,  53],
#         [ 70, 110,  52]],
#
#        [[ 24,  47,  13],
#         [ 24,  47,  13],
#         [ 71, 110,  53],
#         ...,
#         [ 67, 106,  50],
#         [ 68, 107,  51],
#         [ 71, 112,  53]],
#
#        ...,
#
#        [[ 35,  70,  20],
#         [ 22,  44,  12],
#         [ 21,  42,  12],
#         ...,
#         [ 69, 109,  52],
#         [ 65, 103,  49],
#         [ 65, 103,  49]],
#
#        [[ 17,  34,  10],
#         [ 24,  47,  13],
#         [ 22,  44,  12],
#         ...,
#         [ 56,  88,  42],
#         [ 73, 114,  54],
#         [ 70, 110,  52]],
#
#        [[ 29,  58,  17],
#         [ 26,  51,  15],
#         [ 19,  38,  11],
#         ...,
#         [ 56,  88,  42],
#         [ 56,  88,  42],
#         [ 73, 114,  54]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[168, 199, 252],
#         [168, 199, 252],
#         [168, 199, 252],
#         ...,
#         [148, 184, 252],
#         [148, 184, 252],
#         [148, 184, 252]],
#
#        [[168, 199, 252],
#         [168, 199, 252],
#         [168, 199, 252],
#         ...,
#         [148, 184, 252],
#         [148, 184, 252],
#         [149, 184, 252]],
#
#        [[168, 199, 252],
#         [168, 199, 252],
#         [168, 199, 252],
#         ...,
#         [149, 184, 252],
#         [149, 185, 252],
#         [149, 185, 252]],
#
#        ...,
#
#        [[ 92,  89,  87],
#         [200, 194, 195],
#         [200, 194, 195],
#         ...,
#         [ 71, 112,  53],
#         [ 70, 110,  52],
#         [ 67, 105,  50]],
#
#        [[223, 217, 217],
#         [237, 231, 232],
#         [ 57,  56,  53],
#         ...,
#         [ 64, 102,  48],
#         [ 72, 113,  54],
#         [ 67, 106,  50]],
#
#        [[237, 231, 232],
#         [126, 118, 112],
#         [ 57,  56,  53],
#         ...,
#         [ 74, 116,  55],
#         [ 64, 102,  48],
#         [ 70, 110,  53]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[ 10,  20,   6],
#         [ 10,  19,   5],
#         [  9,  18,   5],
#         ...,
#         [ 58,  76,  39],
#         [  0,   0,   0],
#         [ 37,  48,  24]],
#
#        [[ 21,  27,  14],
#         [  8,  16,   4],
#         [  8,  16,   5],
#         ...,
#         [  4,   5,   2],
#         [ 37,  48,  24],
#         [ 60,  78,  40]],
#
#        [[ 22,  44,  12],
#         [ 24,  48,  14],
#         [ 22,  44,  12],
#         ...,
#         [  1,   2,   1],
#         [ 37,  48,  24],
#         [ 38,  49,  25]],
#
#        ...,
#
#        [[117,  84,  57],
#         [104,  74,  51],
#         [ 88,  62,  43],
#         ...,
#         [ 72, 114,  54],
#         [ 65, 103,  49],
#         [ 63,  99,  47]],
#
#        [[107,  76,  52],
#         [ 73,  51,  35],
#         [103,  73,  51],
#         ...,
#         [ 88, 137,  65],
#         [ 72, 114,  54],
#         [ 66, 105,  50]],
#
#        [[ 75,  52,  35],
#         [110,  78,  54],
#         [ 95,  68,  46],
#         ...,
#         [ 56,  88,  42],
#         [ 73, 114,  54],
#         [ 66, 105,  50]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[ 18,  36,  10],
#         [ 40,  79,  22],
#         [ 30,  59,  16],
#         ...,
#         [  2,   5,   1],
#         [ 28,  55,  16],
#         [  4,   7,   2]],
#
#        [[ 35,  69,  19],
#         [ 31,  62,  17],
#         [ 27,  54,  15],
#         ...,
#         [  4,   8,   2],
#         [ 19,  38,  11],
#         [  5,  10,   3]],
#
#        [[ 29,  58,  16],
#         [ 35,  70,  19],
#         [ 30,  60,  17],
#         ...,
#         [ 19,  38,  11],
#         [  8,  17,   5],
#         [  8,  17,   5]],
#
#        ...,
#
#        [[ 72, 113,  54],
#         [ 72, 113,  54],
#         [ 66, 105,  50],
#         ...,
#         [ 68, 107,  51],
#         [ 68, 107,  51],
#         [ 70, 110,  52]],
#
#        [[ 72, 114,  54],
#         [ 65, 103,  49],
#         [ 65, 102,  49],
#         ...,
#         [ 73, 116,  55],
#         [ 72, 114,  54],
#         [ 70, 109,  52]],
#
#        [[ 65, 103,  49],
#         [ 66, 105,  50],
#         [ 71, 111,  53],
#         ...,
#         [ 73, 115,  55],
#         [ 68, 107,  51],
#         [ 70, 110,  52]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[ 56,  88,  42],
#         [ 56,  88,  42],
#         [ 56,  88,  42],
#         ...,
#         [ 70, 110,  52],
#         [ 65, 104,  49],
#         [ 71, 113,  53]],
#
#        [[ 70, 110,  52],
#         [ 70, 109,  52],
#         [ 69, 109,  51],
#         ...,
#         [ 68, 107,  51],
#         [ 70, 111,  53],
#         [ 70, 110,  52]],
#
#        [[ 56,  88,  42],
#         [ 70, 109,  52],
#         [ 67, 105,  50],
#         ...,
#         [ 69, 109,  52],
#         [ 68, 107,  51],
#         [ 71, 113,  53]],
#
#        ...,
#
#        [[ 11,  21,   6],
#         [ 27,  54,  15],
#         [  9,  18,   5],
#         ...,
#         [ 70, 110,  52],
#         [ 70, 110,  52],
#         [ 70, 110,  53]],
#
#        [[ 28,  56,  16],
#         [ 30,  59,  17],
#         [  4,   7,   2],
#         ...,
#         [ 71, 111,  53],
#         [ 67, 105,  50],
#         [ 73, 116,  55]],
#
#        [[ 30,  59,  17],
#         [ 27,  54,  15],
#         [  2,   4,   1],
#         ...,
#         [ 69, 109,  52],
#         [ 67, 105,  50],
#         [ 64, 101,  48]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[ 22,  44,  12],
#         [ 25,  49,  14],
#         [ 22,  44,  12],
#         ...,
#         [ 24,  47,  14],
#         [ 21,  42,  12],
#         [ 19,  37,  11]],
#
#        [[ 23,  46,  13],
#         [ 22,  44,  12],
#         [ 25,  49,  14],
#         ...,
#         [ 22,  43,  12],
#         [ 18,  36,  10],
#         [ 22,  44,  13]],
#
#        [[ 19,  38,  11],
#         [ 24,  47,  13],
#         [ 22,  44,  12],
#         ...,
#         [ 24,  47,  14],
#         [ 21,  41,  12],
#         [ 34,  68,  20]],
#
#        ...,
#
#        [[ 72, 113,  54],
#         [ 67, 105,  50],
#         [ 64, 102,  48],
#         ...,
#         [ 63, 100,  47],
#         [ 69, 109,  52],
#         [ 88, 137,  65]],
#
#        [[ 70, 110,  53],
#         [ 69, 108,  52],
#         [ 66, 105,  50],
#         ...,
#         [ 73, 114,  54],
#         [ 75, 118,  56],
#         [ 68, 107,  51]],
#
#        [[ 66, 104,  49],
#         [ 63,  99,  47],
#         [ 62,  98,  47],
#         ...,
#         [ 69, 108,  51],
#         [ 73, 114,  54],
#         [ 75, 118,  56]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[160, 160, 159],
#         [149, 151, 147],
#         [147, 145, 143],
#         ...,
#         [ 70, 110,  52],
#         [ 56,  88,  42],
#         [ 72, 114,  54]],
#
#        [[146, 140, 141],
#         [156, 156, 155],
#         [143, 141, 138],
#         ...,
#         [ 56,  88,  42],
#         [ 70, 110,  53],
#         [ 67, 106,  50]],
#
#        [[140, 140, 135],
#         [146, 146, 143],
#         [142, 144, 141],
#         ...,
#         [ 66, 104,  49],
#         [ 72, 114,  54],
#         [ 70, 110,  52]],
#
#        ...,
#
#        [[ 73, 116,  55],
#         [ 70, 110,  52],
#         [ 69, 108,  52],
#         ...,
#         [ 59,  92,  44],
#         [ 44,  69,  33],
#         [ 75, 117,  56]],
#
#        [[  0,   0,   0],
#         [ 72, 114,  54],
#         [ 73, 114,  54],
#         ...,
#         [ 64, 101,  48],
#         [ 66, 104,  49],
#         [ 63,  99,  47]],
#
#        [[  0,   0,   0],
#         [  0,   0,   0],
#         [ 69, 109,  52],
#         ...,
#         [ 79, 123,  59],
#         [ 55,  85,  41],
#         [ 65, 102,  49]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[ 55,  72,  37],
#         [ 62,  80,  41],
#         [ 14,  19,   9],
#         ...,
#         [152, 183, 243],
#         [152, 183, 243],
#         [153, 184, 243]],
#
#        [[ 56,  73,  37],
#         [ 70,  91,  47],
#         [ 14,  19,   9],
#         ...,
#         [152, 183, 243],
#         [152, 183, 243],
#         [152, 184, 243]],
#
#        [[ 10,  13,   6],
#         [ 36,  47,  24],
#         [ 43,  56,  29],
#         ...,
#         [152, 183, 243],
#         [152, 183, 243],
#         [152, 184, 243]],
#
#        ...,
#
#        [[ 12,  24,   7],
#         [ 28,  55,  16],
#         [ 13,  26,   7],
#         ...,
#         [ 19,  38,  10],
#         [ 27,  54,  15],
#         [ 32,  63,  18]],
#
#        [[ 20,  40,  11],
#         [ 33,  65,  18],
#         [ 33,  65,  18],
#         ...,
#         [ 19,  38,  10],
#         [ 21,  42,  11],
#         [ 25,  50,  14]],
#
#        [[ 33,  65,  18],
#         [ 33,  65,  18],
#         [ 11,  21,   6],
#         ...,
#         [ 21,  41,  11],
#         [ 19,  37,  10],
#         [ 22,  43,  12]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[168, 199, 252],
#         [168, 199, 252],
#         [168, 199, 252],
#         ...,
#         [151, 186, 252],
#         [151, 186, 252],
#         [151, 186, 252]],
#
#        [[169, 200, 252],
#         [169, 199, 252],
#         [168, 199, 252],
#         ...,
#         [151, 186, 252],
#         [152, 187, 252],
#         [152, 187, 252]],
#
#        [[169, 200, 252],
#         [169, 200, 252],
#         [169, 199, 252],
#         ...,
#         [152, 187, 252],
#         [152, 187, 252],
#         [153, 187, 252]],
#
#        ...,
#
#        [[ 86, 135,  64],
#         [ 61,  96,  46],
#         [ 78, 122,  58],
#         ...,
#         [ 62,  97,  46],
#         [ 62,  97,  46],
#         [ 66, 104,  49]],
#
#        [[ 66, 104,  49],
#         [ 66, 105,  50],
#         [ 66, 105,  50],
#         ...,
#         [ 66, 104,  49],
#         [ 62,  97,  46],
#         [ 62,  97,  46]],
#
#        [[ 66, 104,  49],
#         [ 66, 105,  50],
#         [ 86, 135,  64],
#         ...,
#         [ 67, 106,  50],
#         [ 66, 104,  49],
#         [ 62,  97,  46]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[ 67, 106,  50],
#         [ 82, 129,  61],
#         [ 74, 116,  55],
#         ...,
#         [ 57,  90,  43],
#         [ 63,  99,  47],
#         [ 65, 103,  49]],
#
#        [[ 78, 122,  58],
#         [ 67, 105,  50],
#         [ 88, 137,  65],
#         ...,
#         [ 70, 110,  52],
#         [ 84, 133,  63],
#         [ 64, 102,  48]],
#
#        [[ 66, 104,  49],
#         [ 81, 127,  61],
#         [ 74, 116,  55],
#         ...,
#         [ 66, 105,  50],
#         [ 69, 109,  52],
#         [ 72, 114,  54]],
#
#        ...,
#
#        [[ 67, 105,  50],
#         [ 68, 107,  51],
#         [ 77, 122,  58],
#         ...,
#         [115,  82,  57],
#         [ 73, 114,  54],
#         [ 78,  55,  37]],
#
#        [[ 69, 109,  52],
#         [ 64, 101,  48],
#         [ 62,  98,  47],
#         ...,
#         [ 73, 114,  54],
#         [ 77,  54,  37],
#         [ 88, 137,  65]],
#
#        [[ 71, 112,  53],
#         [ 64, 102,  48],
#         [ 69, 108,  52],
#         ...,
#         [ 73, 114,  54],
#         [ 88, 137,  65],
#         [ 78,  55,  37]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[143, 180, 251],
#         [142, 180, 251],
#         [142, 179, 251],
#         ...,
#         [168, 197, 249],
#         [168, 197, 249],
#         [168, 197, 249]],
#
#        [[143, 180, 251],
#         [142, 180, 251],
#         [142, 179, 251],
#         ...,
#         [168, 197, 249],
#         [168, 197, 249],
#         [168, 197, 249]],
#
#        [[143, 180, 251],
#         [143, 180, 251],
#         [142, 179, 251],
#         ...,
#         [145, 181, 250],
#         [168, 197, 249],
#         [168, 197, 249]],
#
#        ...,
#
#        [[ 63,  50,  30],
#         [ 27,  43,  20],
#         [ 29,  45,  21],
#         ...,
#         [ 79, 124,  59],
#         [ 76, 119,  57],
#         [ 56,  88,  42]],
#
#        [[ 19,  37,  10],
#         [ 82,  59,  41],
#         [ 83,  59,  42],
#         ...,
#         [ 60,  94,  45],
#         [ 62,  97,  46],
#         [ 56,  88,  42]],
#
#        [[ 72,  52,  36],
#         [ 73,  52,  37],
#         [ 72,  52,  36],
#         ...,
#         [ 66, 103,  49],
#         [ 71, 112,  53],
#         [ 62,  97,  46]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[171, 201, 252],
#         [171, 201, 252],
#         [171, 201, 252],
#         ...,
#         [ 43,  56,  28],
#         [ 46,  60,  31],
#         [ 38,  49,  25]],
#
#        [[171, 201, 252],
#         [171, 201, 252],
#         [171, 201, 252],
#         ...,
#         [ 31,  40,  20],
#         [ 46,  60,  31],
#         [ 41,  54,  27]],
#
#        [[171, 201, 252],
#         [171, 201, 252],
#         [171, 201, 252],
#         ...,
#         [ 48,  63,  32],
#         [ 36,  47,  24],
#         [ 42,  54,  28]],
#
#        ...,
#
#        [[157, 190, 252],
#         [157, 190, 252],
#         [157, 190, 252],
#         ...,
#         [171, 201, 252],
#         [171, 201, 252],
#         [164, 195, 252]],
#
#        [[158, 191, 252],
#         [157, 191, 252],
#         [157, 190, 252],
#         ...,
#         [164, 195, 252],
#         [164, 195, 252],
#         [165, 196, 252]],
#
#        [[158, 191, 252],
#         [158, 191, 252],
#         [158, 191, 252],
#         ...,
#         [164, 196, 252],
#         [165, 196, 252],
#         [165, 196, 252]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
#
#
# Count 1:
# Observation: {'pov': array([[[ 23,  31,  16],
#         [  6,   7,   4],
#         [ 21,  28,  14],
#         ...,
#         [ 34,  45,  23],
#         [157, 190, 252],
#         [157, 191, 252]],
#
#        [[ 42,  55,  28],
#         [ 23,  30,  15],
#         [ 32,  41,  21],
#         ...,
#         [156, 190, 252],
#         [157, 190, 252],
#         [157, 190, 252]],
#
#        [[ 43,  56,  28],
#         [ 25,  33,  17],
#         [  9,  11,   6],
#         ...,
#         [156, 189, 252],
#         [156, 190, 252],
#         [157, 190, 252]],
#
#        ...,
#
#        [[ 35,  68,  19],
#         [ 29,  58,  16],
#         [ 21,  42,  12],
#         ...,
#         [ 33,  65,  19],
#         [ 22,  43,  12],
#         [ 28,  55,  16]],
#
#        [[ 29,  57,  16],
#         [  8,  16,   4],
#         [ 36,  71,  20],
#         ...,
#         [ 27,  53,  15],
#         [ 25,  50,  14],
#         [ 32,  62,  18]],
#
#        [[  7,  13,   4],
#         [ 30,  59,  17],
#         [  6,  13,   4],
#         ...,
#         [ 25,  48,  14],
#         [ 22,  44,  13],
#         [ 29,  56,  16]]], dtype=uint8)}
# Reward: 0.0
# Completion: False
# WARNING:minerl.env.malmo.instance.e75b7b:[19:38:14] [Server thread/WARN]: Can't keep up! Did the system time change, or is the server overloaded? Running 163ms behind, skipping 3 tick(s)
# Count 1:
# Observation: {'pov': array([[[140, 178, 252],
#         [139, 178, 252],
#         [139, 178, 252],
#         ...,
#         [141, 179, 252],
#         [141, 179, 252],
#         [142, 180, 252]],
#
#        [[140, 178, 252],
#         [140, 178, 252],
#         [139, 178, 252],
#         ...,
#         [141, 179, 252],
#         [142, 179, 252],
#         [142, 180, 252]],
#
#        [[140, 178, 252],
#         [140, 178, 252],
#         [140, 178, 252],
#         ...,
#         [142, 179, 252],
#         [142, 180, 252],
#         [142, 180, 252]],
#
#        ...,
#
#        [[ 65, 102,  49],
#         [ 64, 101,  48],
#         [ 64, 101,  48],
#         ...,
#         [ 71, 112,  53],
#         [ 71, 112,  53],
#         [ 56,  88,  42]],
#
#        [[ 63,  99,  47],
#         [ 65, 102,  49],
#         [ 70, 110,  52],
#         ...,
#         [ 56,  88,  42],
#         [ 71, 112,  53],
#         [ 71, 112,  53]],
#
#        [[ 69, 108,  52],
#         [ 72, 114,  54],
#         [ 70, 110,  52],
#         ...,
#         [ 56,  88,  42],
#         [ 78, 123,  58],
#         [ 78, 123,  58]]], dtype=uint8)}
# Reward: 0.0
# Completion: True

# %% [markdown]
# # fully_scripted_fixed_seed.py

# %%
import numpy as np
import torch as th
from torch import nn
import gym
import minerl
from tqdm.notebook import tqdm
from colabgymrender.recorder import Recorder
from pyvirtualdisplay import Display
import logging
logging.disable(logging.ERROR)

# %%
def str_to_act(env, actions):
    """
    Simplifies specifying actions for the scripted part of the agent.
    Some examples for a string with a single action:
        'craft:planks'
        'camera:[10,0]'
        'attack'
        'jump'
        ''
    There should be no spaces in single actions, as we use spaces to separate actions with multiple "buttons" pressed:
        'attack sprint forward'
        'forward camera:[0,10]'

    :param env: base MineRL environment.
    :param actions: string of actions.
    :return: dict action, compatible with the base MineRL environment.
    """
    act = env.action_space.noop()
    for action in actions.split():
        if ":" in action:
            k, v = action.split(':')
            if k == 'camera':
                act[k] = eval(v)
            else:
                act[k] = v
        else:
            act[action] = 1
    return act

# %%
def get_action_sequence():
    """
    Specify the action sequence for the agent to execute.
    """
    # get 6 logs:
    action_sequence = []
    action_sequence += [''] * 100  # wait 5 sec
    action_sequence += ['forward'] * 8
    action_sequence += ['attack'] * 61
    action_sequence += ['camera:[-10,0]'] * 7  # look up
    action_sequence += ['attack'] * 61
    action_sequence += ['attack'] * 61
    action_sequence += ['attack'] * 61
    action_sequence += ['attack'] * 61
    action_sequence += [''] * 50
    action_sequence += ['jump']
    action_sequence += ['forward'] * 10
    action_sequence += ['camera:[-10,0]'] * 2
    action_sequence += ['attack'] * 61
    action_sequence += ['attack'] * 61
    action_sequence += ['attack'] * 61
    action_sequence += ['camera:[10,0]'] * 9  # look down
    action_sequence += [''] * 50

    # make planks, sticks, crafting table and wooden pickaxe:
    action_sequence += ['back'] * 2
    action_sequence += ['craft:planks'] * 4
    action_sequence += ['craft:stick'] * 2
    action_sequence += ['craft:crafting_table']
    action_sequence += ['camera:[10,0]'] * 9
    action_sequence += ['jump']
    action_sequence += [''] * 5
    action_sequence += ['place:crafting_table']
    action_sequence += [''] * 10

    # bug: looking straight down at a crafting table doesn't let you craft. So we look up a bit before crafting:
    action_sequence += ['camera:[-1,0]']
    action_sequence += ['nearbyCraft:wooden_pickaxe']
    action_sequence += ['camera:[1,0]']
    action_sequence += [''] * 10
    action_sequence += ['equip:wooden_pickaxe']
    action_sequence += [''] * 10

    # dig down:
    action_sequence += ['attack'] * 900
    action_sequence += [''] * 10

    # make stone pickaxe:
    action_sequence += ['camera:[10,0]'] * 9
    action_sequence += ['jump']
    action_sequence += [''] * 5
    action_sequence += ['place:crafting_table']
    action_sequence += [''] * 10

    # craft stone pickaxe
    action_sequence += ['camera:[-1,0]']
    action_sequence += ['nearbyCraft:stone_pickaxe']
    action_sequence += ['camera:[1,0]']
    action_sequence += [''] * 10
    action_sequence += ['equip:stone_pickaxe']
    action_sequence += [''] * 10

    # craft furnace
    action_sequence += ['nearbyCraft:furnace']

    # place furnace
    action_sequence += ['camera:[10,0]'] * 9
    action_sequence += ['jump']
    action_sequence += [''] * 5
    action_sequence += ['place:furnace']
    action_sequence += [''] * 10

    return action_sequence

# %%
display = Display(visible=0, size=(400, 300))
display.start();

# %%
env = gym.make('MineRLObtainDiamond-v0')
env = Recorder(env, './video', fps=60)

# %%
action_sequence = get_action_sequence()

env.seed(21)
obs = env.reset();

total_reward = 0
for i, action in enumerate(tqdm(action_sequence)):
    obs, reward, done, _ = env.step(str_to_act(env, action))
    total_reward += reward
    if done:
        break

env.release()
#env.play()
env.close()

print(f'\nTotal reward = {total_reward}')
# Out:
#   0%|          | 0/1771 [00:00<?, ?it/s]
# Total reward = 67.0

# %% [markdown]
# # bc+scripted.py

# %%
import numpy as np
import torch as th
from torch import nn
import gym
import minerl
from tqdm.notebook import tqdm
from colabgymrender.recorder import Recorder
from pyvirtualdisplay import Display
import logging
logging.disable(logging.ERROR)

# %%
class NatureCNN(nn.Module):
    """
    CNN from DQN nature paper:
        Mnih, Volodymyr, et al.
        "Human-level control through deep reinforcement learning."
        Nature 518.7540 (2015): 529-533.

    :param input_shape: A three-item tuple telling image dimensions in (C, H, W)
    :param output_dim: Dimensionality of the output vector
    """

    def __init__(self, input_shape, output_dim):
        super().__init__()
        n_input_channels = input_shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with th.no_grad():
            n_flatten = self.cnn(th.zeros(1, *input_shape)).shape[1]

        self.linear = nn.Sequential(
            nn.Linear(n_flatten, 512),
            nn.ReLU(),
            nn.Linear(512, output_dim)
        )

    def forward(self, observations: th.Tensor) -> th.Tensor:
        return self.linear(self.cnn(observations))

# %%
class ActionShaping(gym.ActionWrapper):
    """
    The default MineRL action space is the following dict:

    Dict(attack:Discrete(2),
         back:Discrete(2),
         camera:Box(low=-180.0, high=180.0, shape=(2,)),
         craft:Enum(crafting_table,none,planks,stick,torch),
         equip:Enum(air,iron_axe,iron_pickaxe,none,stone_axe,stone_pickaxe,wooden_axe,wooden_pickaxe),
         forward:Discrete(2),
         jump:Discrete(2),
         left:Discrete(2),
         nearbyCraft:Enum(furnace,iron_axe,iron_pickaxe,none,stone_axe,stone_pickaxe,wooden_axe,wooden_pickaxe),
         nearbySmelt:Enum(coal,iron_ingot,none),
         place:Enum(cobblestone,crafting_table,dirt,furnace,none,stone,torch),
         right:Discrete(2),
         sneak:Discrete(2),
         sprint:Discrete(2))

    It can be viewed as:
         - buttons, like attack, back, forward, sprint that are either pressed or not.
         - mouse, i.e. the continuous camera action in degrees. The two values are pitch (up/down), where up is
           negative, down is positive, and yaw (left/right), where left is negative, right is positive.
         - craft/equip/place actions for items specified above.
    So an example action could be sprint + forward + jump + attack + turn camera, all in one action.

    This wrapper makes the action space much smaller by selecting a few common actions and making the camera actions
    discrete. You can change these actions by changing self._actions below. That should just work with the RL agent,
    but would require some further tinkering below with the BC one.
    """
    def __init__(self, env, camera_angle=10, always_attack=False):
        super().__init__(env)

        self.camera_angle = camera_angle
        self.always_attack = always_attack
        self._actions = [
            [('attack', 1)],
            [('forward', 1)],
            # [('back', 1)],
            # [('left', 1)],
            # [('right', 1)],
            # [('jump', 1)],
            # [('forward', 1), ('attack', 1)],
            # [('craft', 'planks')],
            [('forward', 1), ('jump', 1)],
            [('camera', [-self.camera_angle, 0])],
            [('camera', [self.camera_angle, 0])],
            [('camera', [0, self.camera_angle])],
            [('camera', [0, -self.camera_angle])],
        ]

        self.actions = []
        for actions in self._actions:
            act = self.env.action_space.noop()
            for a, v in actions:
                act[a] = v
            if self.always_attack:
                act['attack'] = 1
            self.actions.append(act)

        self.action_space = gym.spaces.Discrete(len(self.actions))

    def action(self, action):
        return self.actions[action]

# %%
def dataset_action_batch_to_actions(dataset_actions, camera_margin=5):
    """
    Turn a batch of actions from dataset (`batch_iter`) to a numpy
    array that corresponds to batch of actions of ActionShaping wrapper (_actions).

    Camera margin sets the threshold what is considered "moving camera".

    Note: Hardcoded to work for actions in ActionShaping._actions, with "intuitive"
        ordering of actions.
        If you change ActionShaping._actions, remember to change this!

    Array elements are integers corresponding to actions, or "-1"
    for actions that did not have any corresponding discrete match.
    """
    # There are dummy dimensions of shape one
    camera_actions = dataset_actions["camera"].squeeze()
    attack_actions = dataset_actions["attack"].squeeze()
    forward_actions = dataset_actions["forward"].squeeze()
    jump_actions = dataset_actions["jump"].squeeze()
    batch_size = len(camera_actions)
    actions = np.zeros((batch_size,), dtype=np.int)

    for i in range(len(camera_actions)):
        # Moving camera is most important (horizontal first)
        if camera_actions[i][0] < -camera_margin:
            actions[i] = 3
        elif camera_actions[i][0] > camera_margin:
            actions[i] = 4
        elif camera_actions[i][1] > camera_margin:
            actions[i] = 5
        elif camera_actions[i][1] < -camera_margin:
            actions[i] = 6
        elif forward_actions[i] == 1:
            if jump_actions[i] == 1:
                actions[i] = 2
            else:
                actions[i] = 1
        elif attack_actions[i] == 1:
            actions[i] = 0
        else:
            # No reasonable mapping (would be no-op)
            actions[i] = -1
    return actions

# %%
def train():
    data = minerl.data.make("MineRLTreechop-v0",  data_dir='data', num_workers=4)

    # We know ActionShaping has seven discrete actions, so we create
    # a network to map images to seven values (logits), which represent
    # likelihoods of selecting those actions
    network = NatureCNN((3, 64, 64), 7)
    optimizer = th.optim.Adam(network.parameters(), lr=LEARNING_RATE)
    loss_function = nn.CrossEntropyLoss()

    iter_count = 0
    losses = []
    for dataset_obs, dataset_actions, _, _, _ in tqdm(data.batch_iter(num_epochs=EPOCHS, batch_size=32, seq_len=1)):
        # We only use pov observations (also remove dummy dimensions)
        obs = dataset_obs["pov"].squeeze().astype(np.float32)
        # Transpose observations to be channel-first (BCHW instead of BHWC)
        obs = obs.transpose(0, 3, 1, 2)
        # Normalize observations
        obs /= 255.0

        # Actions need bit more work
        actions = dataset_action_batch_to_actions(dataset_actions)

        # Remove samples that had no corresponding action
        mask = actions != -1
        obs = obs[mask]
        actions = actions[mask]

        # Obtain logits of each action
        logits = network(th.from_numpy(obs).float())

        # Minimize cross-entropy with target labels.
        # We could also compute the probability of demonstration actions and
        # maximize them.
        loss = loss_function(logits, th.from_numpy(actions).long())

        # Standard PyTorch update
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        iter_count += 1
        losses.append(loss.item())
        if (iter_count % 1000) == 0:
            mean_loss = sum(losses) / len(losses)
            tqdm.write("Iteration {}. Loss {:<10.3f}".format(iter_count, mean_loss))
            losses.clear()

    th.save(network.state_dict(), TRAIN_MODEL_NAME)
    del data

# %%
def str_to_act(env, actions):
    """
    Simplifies specifying actions for the scripted part of the agent.
    Some examples for a string with a single action:
        'craft:planks'
        'camera:[10,0]'
        'attack'
        'jump'
        ''
    There should be no spaces in single actions, as we use spaces to separate actions with multiple "buttons" pressed:
        'attack sprint forward'
        'forward camera:[0,10]'

    :param env: base MineRL environment.
    :param actions: string of actions.
    :return: dict action, compatible with the base MineRL environment.
    """
    act = env.action_space.noop()
    for action in actions.split():
        if ":" in action:
            k, v = action.split(':')
            if k == 'camera':
                act[k] = eval(v)
            else:
                act[k] = v
        else:
            act[action] = 1
    return act

# %%
def get_action_sequence():
    """
    Specify the action sequence for the agent to execute.
    """
    # make planks, sticks, crafting table and wooden pickaxe:
    action_sequence = []
    action_sequence += [''] * 100
    action_sequence += ['craft:planks'] * 4
    action_sequence += ['craft:stick'] * 2
    action_sequence += ['craft:crafting_table']
    action_sequence += ['camera:[10,0]'] * 18
    action_sequence += ['attack'] * 20
    action_sequence += [''] * 10
    action_sequence += ['jump']
    action_sequence += [''] * 5
    action_sequence += ['place:crafting_table']
    action_sequence += [''] * 10

    # bug: looking straight down at a crafting table doesn't let you craft. So we look up a bit before crafting.
    action_sequence += ['camera:[-1,0]']
    action_sequence += ['nearbyCraft:wooden_pickaxe']
    action_sequence += ['camera:[1,0]']
    action_sequence += [''] * 10
    action_sequence += ['equip:wooden_pickaxe']
    action_sequence += [''] * 10

    # dig down:
    action_sequence += ['attack'] * 900
    action_sequence += [''] * 10

    # make stone pickaxe:
    action_sequence += ['camera:[10,0]'] * 9
    action_sequence += ['jump']
    action_sequence += [''] * 5
    action_sequence += ['place:crafting_table']
    action_sequence += [''] * 10

    # craft stone pickaxe
    action_sequence += ['camera:[-1,0]']
    action_sequence += ['nearbyCraft:stone_pickaxe']
    action_sequence += ['camera:[1,0]']
    action_sequence += [''] * 10
    action_sequence += ['equip:stone_pickaxe']
    action_sequence += [''] * 10

    # craft furnace
    action_sequence += ['nearbyCraft:furnace']

    # place furnace
    action_sequence += ['camera:[10,0]'] * 9
    action_sequence += ['jump']
    action_sequence += [''] * 5
    action_sequence += ['place:furnace']
    action_sequence += [''] * 10

    return action_sequence

# %%
# Parameters:
EPOCHS = 3  # How many times we train over the dataset.
LEARNING_RATE = 0.0001  # Learning rate for the neural network.

TRAIN_MODEL_NAME = 'another_potato.pth'  # name to use when saving the trained agent.
TEST_MODEL_NAME = 'another_potato.pth'  # name to use when loading the trained agent.

TEST_EPISODES = 5  # number of episodes to test the agent for.
MAX_TEST_EPISODE_LEN = 5000  # 18k is the default for MineRLObtainDiamond.
TREECHOP_STEPS = 2000  # number of steps to run BC lumberjack for in evaluations.

# %%
minerl.data.download(directory='data', environment='MineRLTreechop-v0');
# Out:
# Download: https://minerl.s3.amazonaws.com/v4/MineRLTreechop-v0.tar: 100%|██████████| 1511.0/1510.73792 [00:30<00:00, 48.85MB/s]

# %%
display = Display(visible=0, size=(400, 300))
display.start();

# %%
train()  # only need to run this once.
# Out:
# 0it [00:00, ?it/s]
# Iteration 1000. Loss 1.084
# Iteration 2000. Loss 0.968
# Iteration 3000. Loss 0.961
# Iteration 4000. Loss 0.931
# Iteration 5000. Loss 0.939
# Iteration 6000. Loss 0.869
# Iteration 7000. Loss 0.869
# Iteration 8000. Loss 0.860
# Iteration 9000. Loss 0.860
# Iteration 10000. Loss 0.898
# Iteration 11000. Loss 0.889
# Iteration 12000. Loss 0.844
# Iteration 13000. Loss 0.827
# Iteration 14000. Loss 0.833
# Iteration 15000. Loss 0.796
# Iteration 16000. Loss 0.844
# Iteration 17000. Loss 0.789
# Iteration 18000. Loss 0.809
# Iteration 19000. Loss 0.830
# Iteration 20000. Loss 0.806
# Iteration 21000. Loss 0.813
# Iteration 22000. Loss 0.844
# Iteration 23000. Loss 0.838
# Iteration 24000. Loss 0.838
# Iteration 25000. Loss 0.822
# Iteration 26000. Loss 0.826
# Iteration 27000. Loss 0.773
# Iteration 28000. Loss 0.786
# Iteration 29000. Loss 0.795
# Iteration 30000. Loss 0.803
# Iteration 31000. Loss 0.782
# Iteration 32000. Loss 0.776
# Iteration 33000. Loss 0.788
# Iteration 34000. Loss 0.802
# Iteration 35000. Loss 0.823
# Iteration 36000. Loss 0.785
# Iteration 37000. Loss 0.767
# Iteration 38000. Loss 0.814

# %%
env = gym.make('MineRLObtainDiamond-v0')

env1 = Recorder(env, './video', fps=60)  # saving environment before action shaping to use with scripted part
env = ActionShaping(env1, always_attack=True)

# %%
network = NatureCNN((3, 64, 64), 7)
network.load_state_dict(th.load(TEST_MODEL_NAME))

num_actions = env.action_space.n
action_list = np.arange(num_actions)

action_sequence = get_action_sequence()

for episode in range(TEST_EPISODES):
    obs = env.reset()
    done = False
    total_reward = 0
    steps = 0

    # BC part to get some logs:
    for i in tqdm(range(TREECHOP_STEPS)):
        # Process the action:
        #   - Add/remove batch dimensions
        #   - Transpose image (needs to be channels-last)
        #   - Normalize image
        obs = th.from_numpy(obs['pov'].transpose(2, 0, 1)[None].astype(np.float32) / 255)
        # Turn logits into probabilities
        probabilities = th.softmax(network(obs), dim=1)[0]
        # Into numpy
        probabilities = probabilities.detach().cpu().numpy()
        # Sample action according to the probabilities
        action = np.random.choice(action_list, p=probabilities)

        obs, reward, done, info = env.step(action)
        total_reward += reward
        steps += 1
        if done:
            break

    # scripted part to use the logs:
    if not done:
        for i, action in enumerate(tqdm(action_sequence[:MAX_TEST_EPISODE_LEN - TREECHOP_STEPS])):
            obs, reward, done, _ = env1.step(str_to_act(env1, action))
            total_reward += reward
            steps += 1
            if done:
                break

    env1.release()
    #env1.play()
    print(f'Episode #{episode + 1} reward: {total_reward}\t\t episode length: {steps}\n')
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/1183 [00:00<?, ?it/s]
# Episode #1 reward: 11.0		 episode length: 2794
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/1183 [00:00<?, ?it/s]
# Episode #2 reward: 67.0		 episode length: 3183
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/1183 [00:00<?, ?it/s]
# Episode #3 reward: 7.0		 episode length: 3183
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Episode #4 reward: 0.0		 episode length: 815
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/1183 [00:00<?, ?it/s]
# Episode #5 reward: 11.0		 episode length: 2593
